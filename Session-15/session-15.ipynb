# %%
import csv
from collections import namedtuple
import pandas as pd
import datetime

filename = "nyc_parking_tickets_extract.csv"

# %%
data = pd.read_csv(filename)

column_name = []

column_name= (col.replace(" ", "") for col in data.columns)

ParkingTicket = namedtuple('ParkingTicket', column_name)
ticket = (ParkingTicket(*row) for index, row in data.iterrows())

# %%
type(ticket)
# Out:
# generator

# %%
next(ticket)
# Out:
# ParkingTicket(SummonsNumber=4006478550, PlateID='VAD7274', RegistrationState='VA', PlateType='PAS', IssueDate='10/5/2016', ViolationCode=5, VehicleBodyType='4D', VehicleMake='BMW', ViolationDescription='BUS LANE VIOLATION')

# %%
next(ticket)
# Out:
# ParkingTicket(SummonsNumber=4006462396, PlateID='22834JK', RegistrationState='NY', PlateType='COM', IssueDate='9/30/2016', ViolationCode=5, VehicleBodyType='VAN', VehicleMake='CHEVR', ViolationDescription='BUS LANE VIOLATION')

# %% [markdown]
# ## Calculate the number of violations by car make.

# %%
data1 = pd.read_csv(filename)

# %%
data1.head()
# Out:
#    Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 0      4006478550   VAD7274                 VA        PAS   10/5/2016
# 1      4006462396   22834JK                 NY        COM   9/30/2016
# 2      4007117810   21791MG                 NY        COM   4/10/2017
# 3      4006265037   FZX9232                 NY        PAS   8/23/2016
# 4      4006535600  N203399C                 NY        OMT  10/19/2016
#
#    Violation Code Vehicle Body Type Vehicle Make Violation Description
# 0               5                4D          BMW    BUS LANE VIOLATION
# 1               5               VAN        CHEVR    BUS LANE VIOLATION
# 2               5               VAN        DODGE    BUS LANE VIOLATION
# 3               5              SUBN         FORD    BUS LANE VIOLATION
# 4               5              SUBN         FORD    BUS LANE VIOLATION

# %%
data1[['Vehicle Make', 'Violation Code']].head(10)
# Out:
#   Vehicle Make  Violation Code
# 0          BMW               5
# 1        CHEVR               5
# 2        DODGE               5
# 3         FORD               5
# 4         FORD               5
# 5        FRUEH               5
# 6        HONDA               5
# 7        LINCO               5
# 8        TOYOT               5
# 9        TOYOT               5

# %%
marks_list = data1['Violation Code'].tolist()

# %%
len(marks_list)

# %%
d = data1.groupby('Vehicle Make')

# %%
d.first()
# Out:
#               Summons Number Plate ID Registration State Plate Type  \
# Vehicle Make
# ACURA             8378547530  FWZ8815                 NY        PAS
# AM/T              8394016790  31690BB                 NY        OMR
# AUDI              8489750210  6DQT356                 CA        PAS
# BMW               4006478550  VAD7274                 VA        PAS
# BSA               8512270482   Y26CRJ                 NJ        PAS
# BUICK             8236569895  EPY9505                 NY        PAS
# CADIL             5096061966  HRC9475                 NY        PAS
# CHEVR             4006462396  22834JK                 NY        COM
# CHRYS             5094906770   G30ESY                 NJ        PAS
# CITRO             7623299300   530LAW                 FL        PAS
# DODGE             4007117810  21791MG                 NY        COM
# FIAT              1420122800  AB80443                 CT        PAS
# FIR               5092906534   V84FXV                 NJ        PAS
# ...

# %%
# Out:
# 'User_Label_not_Configured_for_Service-profile'
